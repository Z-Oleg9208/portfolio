# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Загрузка-и-изучение-данных" data-toc-modified-id="Загрузка-и-изучение-данных-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Загрузка и изучение данных</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Проверим,-что-эффективность-обогащения-рассчитана-правильно.-Вычислим-её-на-обучающей-выборке-для-признака-rougher.output.recovery.-Найдем-MAE-между-нашими-расчётами-и-значением-признака." data-toc-modified-id="Проверим,-что-эффективность-обогащения-рассчитана-правильно.-Вычислим-её-на-обучающей-выборке-для-признака-rougher.output.recovery.-Найдем-MAE-между-нашими-расчётами-и-значением-признака.-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Проверим, что эффективность обогащения рассчитана правильно. Вычислим её на обучающей выборке для признака <code>rougher.output.recovery</code>. Найдем MAE между нашими расчётами и значением признака.</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Проанализируем-признаки,-недоступные-в-тестовой-выборке.-Что-это-за-параметры?-К-какому-типу-относятся?" data-toc-modified-id="Проанализируем-признаки,-недоступные-в-тестовой-выборке.-Что-это-за-параметры?-К-какому-типу-относятся?-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Проанализируем признаки, недоступные в тестовой выборке. Что это за параметры? К какому типу относятся?</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Предобработка данных</a></span></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Посмотрим,-как-меняется-концентрация-металлов-(Au,-Ag,-Pb)-на-различных-этапах:-в-сырье,-в-черновом-концентрате,-в-концентрате-после-первой-очистки-и-в-финальном-концентрате.-Какие-особенности-имеют-распределения?." data-toc-modified-id="Посмотрим,-как-меняется-концентрация-металлов-(Au,-Ag,-Pb)-на-различных-этапах:-в-сырье,-в-черновом-концентрате,-в-концентрате-после-первой-очистки-и-в-финальном-концентрате.-Какие-особенности-имеют-распределения?.-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Посмотрим, как меняется концентрация металлов (Au, Ag, Pb) на различных этапах: в сырье, в черновом концентрате, в концентрате после первой очистки и в финальном концентрате. Какие особенности имеют распределения?.</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Сравним-распределения-размеров-гранул-исходного-сырья-на-обучающей-и-тестовой-выборках." data-toc-modified-id="Сравним-распределения-размеров-гранул-исходного-сырья-на-обучающей-и-тестовой-выборках.-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Сравним распределения размеров гранул исходного сырья на обучающей и тестовой выборках.</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Исследуем-суммарную-концентрацию-металлов-на-разных-стадиях:-в-сырье,-в-черновом-концентрате,-в-концентрате-после-первой-очистки-и-в-финальном-концентрате." data-toc-modified-id="Исследуем-суммарную-концентрацию-металлов-на-разных-стадиях:-в-сырье,-в-черновом-концентрате,-в-концентрате-после-первой-очистки-и-в-финальном-концентрате.-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Исследуем суммарную концентрацию металлов на разных стадиях: в сырье, в черновом концентрате, в концентрате после первой очистки и в финальном концентрате.</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li></ul></li><li><span><a href="#Модель" data-toc-modified-id="Модель-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Модель</a></span><ul class="toc-item"><li><span><a href="#Подберем-модель-для-предсказания-эффективности-обогащения-чернового-концентрата-(rougher.output.recovery)" data-toc-modified-id="Подберем-модель-для-предсказания-эффективности-обогащения-чернового-концентрата-(rougher.output.recovery)-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Подберем модель для предсказания эффективности обогащения чернового концентрата (rougher.output.recovery)</a></span></li><li><span><a href="#Подберем-модель-для-предсказания-эффективности-обогащения-финального-концентрата-(final.output.recovery)" data-toc-modified-id="Подберем-модель-для-предсказания-эффективности-обогащения-финального-концентрата-(final.output.recovery)-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Подберем модель для предсказания эффективности обогащения финального концентрата (final.output.recovery)</a></span></li></ul></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Вывод</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Вывод</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Восстановление золота из руды

# %% [markdown]
# Подготовьте прототип модели машинного обучения для «Цифры». Компания разрабатывает решения для эффективной работы промышленных предприятий.
#
# Модель должна предсказать коэффициент восстановления золота из золотосодержащей руды. Используйте данные с параметрами добычи и очистки.
#
# Модель поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.
#
# Описание данных
#
# **Технологический процесс**
# - Rougher feed — исходное сырье
# - Rougher additions (или reagent additions) — флотационные реагенты: Xanthate, Sulphate, Depressant
#     - Xanthate — ксантогенат (промотер, или активатор флотации);
#     - Sulphate — сульфат (на данном производстве сульфид натрия);
#     - Depressant — депрессант (силикат натрия).
# - Rougher process (англ. «грубый процесс») — флотация
# - Rougher tails — отвальные хвосты
# - Float banks — флотационная установка
# - Cleaner process — очистка
# - Rougher Au — черновой концентрат золота
# - Final Au — финальный концентрат золота
#
# **Параметры этапов**
# - air amount — объём воздуха
# - fluid levels — уровень жидкости
# - feed size — размер гранул сырья
# - feed rate — скорость подачи
#
# **Наименование признаков**
#
# Наименование признаков должно быть такое:
#
# [этап].[тип_параметра].[название_параметра]
#
# Пример: rougher.input.feed_ag
#
# Возможные значения для блока [этап]:
#
# - rougher — флотация
# - primary_cleaner — первичная очистка
# - secondary_cleaner — вторичная очистка
# - final — финальные характеристики
#
# Возможные значения для блока [тип_параметра]:
#
# - input — параметры сырья
# - output — параметры продукта
# - state — параметры, характеризующие текущее состояние этапа
# - calculation — расчётные характеристики

# %% [markdown]
# ## Подготовка данных

# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression, Lasso
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import make_scorer
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.pipeline import Pipeline
from sklearn.dummy import DummyRegressor

# %%
# настройки вывода данных
pd.set_option('display.max_columns', None)
pd.options.display.float_format='{:,.2f}'.format

# %% [markdown]
# ### Загрузка и изучение данных

# %%
# загрузка данных
df_full = pd.read_csv('/datasets/gold_industry_full.csv')
train = pd.read_csv('/datasets/gold_industry_train.csv')
test = pd.read_csv('/datasets/gold_industry_test.csv')

# %%
df_full.head()
# Out:
#                   date  rougher.input.feed_au  rougher.input.feed_ag  \
# 0  2016-01-15 00:00:00                   6.49                   6.10
# 1  2016-01-15 01:00:00                   6.48                   6.16
# 2  2016-01-15 02:00:00                   6.36                   6.12
# 3  2016-01-15 03:00:00                   6.12                   6.04
# 4  2016-01-15 04:00:00                   5.66                   6.06
#
#    rougher.input.feed_pb  rougher.input.feed_sol  rougher.input.feed_rate  \
# 0                   2.28                   36.81                   523.55
# 1                   2.27                   35.75                   525.29
# 2                   2.16                   35.97                   530.03
# 3                   2.04                   36.86                   542.59
# 4                   1.79                   34.35                   540.53
#
#    rougher.input.feed_size  rougher.input.floatbank10_sulfate  \
# ...

# %%
train.head()
# Out:
#                   date  rougher.input.feed_au  rougher.input.feed_ag  \
# 0  2016-01-15 00:00:00                   6.49                   6.10
# 1  2016-01-15 01:00:00                   6.48                   6.16
# 2  2016-01-15 02:00:00                   6.36                   6.12
# 3  2016-01-15 03:00:00                   6.12                   6.04
# 4  2016-01-15 04:00:00                   5.66                   6.06
#
#    rougher.input.feed_pb  rougher.input.feed_sol  rougher.input.feed_rate  \
# 0                   2.28                   36.81                   523.55
# 1                   2.27                   35.75                   525.29
# 2                   2.16                   35.97                   530.03
# 3                   2.04                   36.86                   542.59
# 4                   1.79                   34.35                   540.53
#
#    rougher.input.feed_size  rougher.input.floatbank10_sulfate  \
# ...

# %%
test.head()
# Out:
#                   date  rougher.input.feed_au  rougher.input.feed_ag  \
# 0  2017-12-09 14:59:59                   4.37                   6.16
# 1  2017-12-09 15:59:59                   4.36                   6.05
# 2  2017-12-09 16:59:59                   5.08                   6.08
# 3  2017-12-09 17:59:59                   5.15                   6.08
# 4  2017-12-09 18:59:59                   5.74                   6.17
#
#    rougher.input.feed_pb  rougher.input.feed_sol  rougher.input.feed_rate  \
# 0                   3.88                   39.14                   555.82
# 1                   3.90                   39.71                   544.73
# 2                   4.56                   37.21                   558.16
# 3                   4.77                   36.81                   539.71
# 4                   4.51                   37.81                   558.71
#
#    rougher.input.feed_size  rougher.input.floatbank10_sulfate  \
# ...

# %%
df_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19439 entries, 0 to 19438
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                19439 non-null  object
#  1   rougher.input.feed_au                               19439 non-null  float64
#  2   rougher.input.feed_ag                               19439 non-null  float64
#  3   rougher.input.feed_pb                               19339 non-null  float64
#  4   rougher.input.feed_sol                              19340 non-null  float64
#  5   rougher.input.feed_rate                             19428 non-null  float64
#  6   rougher.input.feed_size                             19294 non-null  float64
#  7   rougher.input.floatbank10_sulfate                   19405 non-null  float64
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14579 entries, 0 to 14578
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                14579 non-null  object
#  1   rougher.input.feed_au                               14579 non-null  float64
#  2   rougher.input.feed_ag                               14579 non-null  float64
#  3   rougher.input.feed_pb                               14507 non-null  float64
#  4   rougher.input.feed_sol                              14502 non-null  float64
#  5   rougher.input.feed_rate                             14572 non-null  float64
#  6   rougher.input.feed_size                             14478 non-null  float64
#  7   rougher.input.floatbank10_sulfate                   14548 non-null  float64
# ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4860 entries, 0 to 4859
# Data columns (total 53 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   date                                        4860 non-null   object
#  1   rougher.input.feed_au                       4860 non-null   float64
#  2   rougher.input.feed_ag                       4860 non-null   float64
#  3   rougher.input.feed_pb                       4832 non-null   float64
#  4   rougher.input.feed_sol                      4838 non-null   float64
#  5   rougher.input.feed_rate                     4856 non-null   float64
#  6   rougher.input.feed_size                     4816 non-null   float64
#  7   rougher.input.floatbank10_sulfate           4857 non-null   float64
#  8   rougher.input.floatbank10_xanthate          4859 non-null   float64
# ...

# %% [markdown]
# **Проверим данные на явные дубликаты**

# %%
df_full.duplicated().sum()
# Out:
# 0

# %%
train.duplicated().sum()
# Out:
# 0

# %%
test.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Вывод
# - В данных имеются незначительные пропуски
# - Явные дубликаты отсутствуют
# - Во всех ДатаФреймах типданных в столбце `date` не соответствует типу данных Pandas

# %% [markdown]
# ### Проверим, что эффективность обогащения рассчитана правильно. Вычислим её на обучающей выборке для признака `rougher.output.recovery`. Найдем MAE между нашими расчётами и значением признака.

# %%
train
# Out:
#                       date  rougher.input.feed_au  rougher.input.feed_ag  \
# 0      2016-01-15 00:00:00                   6.49                   6.10
# 1      2016-01-15 01:00:00                   6.48                   6.16
# 2      2016-01-15 02:00:00                   6.36                   6.12
# 3      2016-01-15 03:00:00                   6.12                   6.04
# 4      2016-01-15 04:00:00                   5.66                   6.06
# ...                    ...                    ...                    ...
# 14574  2017-12-09 09:59:59                   4.60                   5.82
# 14575  2017-12-09 10:59:59                   4.66                   5.84
# 14576  2017-12-09 11:59:59                   5.34                   6.09
# 14577  2017-12-09 12:59:59                   4.84                   6.12
# 14578  2017-12-09 13:59:59                   4.53                   5.97
#
#        rougher.input.feed_pb  rougher.input.feed_sol  rougher.input.feed_rate  \
# ...

# %%
C = train['rougher.output.concentrate_au']
F = train['rougher.input.feed_au']
T = train['rougher.output.tail_au']

# %%
recovery_tabl = train['rougher.output.recovery'].to_frame()
recovery_tabl['recovery'] = (C * (F - T))/(F * (C - T)) * 100
mae = abs(sum(recovery_tabl['rougher.output.recovery'])
                                   - sum(recovery_tabl['recovery'])) / len(recovery_tabl['recovery'])
print(f'MAE = {mae:.5f}')
# Out:
# MAE = 0.00000

# %% [markdown]
# #### Вывод
#
# Средняя абсолютная ошибка (MAE) между `rougher.output.recovery` и расчетным значением recovery равняется 0 с точностью до пяти знаков после запятой. Это означает, что `rougher.output.recovery` расчитано верно. **Дальнейшее использование данного целевого признака для обучения модели является корректным.**

# %% [markdown]
# ### Проанализируем признаки, недоступные в тестовой выборке. Что это за параметры? К какому типу относятся?

# %%
params = df_full.drop(test.columns, axis=1)
params
# Out:
#        rougher.calculation.sulfate_to_au_concentrate  \
# 0                                          41,885.71
# 1                                          42,050.86
# 2                                          42,018.10
# 3                                          42,029.45
# 4                                          42,125.35
# ...                                              ...
# 19434                                      42,054.38
# 19435                                      41,864.19
# 19436                                      42,074.09
# 19437                                      42,019.29
# 19438                                      41,882.13
#
#        rougher.calculation.floatbank10_sulfate_to_au_feed  \
# 0                                               3,481.78
# 1                                               3,498.37
# 2                                               3,495.35
# 3                                               3,498.58
# ...

# %%
params.dtypes
# Out:
# rougher.calculation.sulfate_to_au_concentrate         float64
# rougher.calculation.floatbank10_sulfate_to_au_feed    float64
# rougher.calculation.floatbank11_sulfate_to_au_feed    float64
# rougher.calculation.au_pb_ratio                       float64
# rougher.output.concentrate_au                         float64
# rougher.output.concentrate_ag                         float64
# rougher.output.concentrate_pb                         float64
# rougher.output.concentrate_sol                        float64
# rougher.output.recovery                               float64
# rougher.output.tail_au                                float64
# rougher.output.tail_ag                                float64
# rougher.output.tail_pb                                float64
# rougher.output.tail_sol                               float64
# primary_cleaner.output.concentrate_au                 float64
# primary_cleaner.output.concentrate_ag                 float64
# ...

# %% [markdown]
# #### Вывод
# - Параметры имеют тип данных вещественное число (float64).
# - Отсутствующие параметры в тестовой выборке: 1) Доля au, ag, pb и sol в концентрате до флотации/очистки. 2)Концентрат au, ag, pb и sol после флотации/очистки. 3)доля au, ag, pb и sol в отвальных хвостах после флотации/очистки. 4) Расчётная эффективность флотации/очистки.

# %% [markdown]
# ### Предобработка данных

# %%
# удалим объекты с пропущенными значениями в признаках

df_full = df_full.dropna()
train =train.dropna()
test = test.dropna()

# %% [markdown]
# **В столбце `date` типданных не соответствует типу данных Pandas. Изменим тип данных.**

# %%
df_full.date = pd.to_datetime(df_full.date, format='%Y-%m-%d %H:%M:%S')
df_full.dtypes
# Out:
# date                      datetime64[ns]
# rougher.input.feed_au            float64
# rougher.input.feed_ag            float64
# rougher.input.feed_pb            float64
# rougher.input.feed_sol           float64
#                                ...
# final.output.recovery            float64
# final.output.tail_au             float64
# final.output.tail_ag             float64
# final.output.tail_pb             float64
# final.output.tail_sol            float64
# Length: 87, dtype: object

# %%
train.date = pd.to_datetime(train.date, format='%Y-%m-%d %H:%M:%S')
train.dtypes
# Out:
# date                      datetime64[ns]
# rougher.input.feed_au            float64
# rougher.input.feed_ag            float64
# rougher.input.feed_pb            float64
# rougher.input.feed_sol           float64
#                                ...
# final.output.recovery            float64
# final.output.tail_au             float64
# final.output.tail_ag             float64
# final.output.tail_pb             float64
# final.output.tail_sol            float64
# Length: 87, dtype: object

# %%
test.date = pd.to_datetime(test.date, format='%Y-%m-%d %H:%M:%S')
test.dtypes
# Out:
# date                                          datetime64[ns]
# rougher.input.feed_au                                float64
# rougher.input.feed_ag                                float64
# rougher.input.feed_pb                                float64
# rougher.input.feed_sol                               float64
# rougher.input.feed_rate                              float64
# rougher.input.feed_size                              float64
# rougher.input.floatbank10_sulfate                    float64
# rougher.input.floatbank10_xanthate                   float64
# rougher.state.floatbank10_a_air                      float64
# rougher.state.floatbank10_a_level                    float64
# rougher.state.floatbank10_b_air                      float64
# rougher.state.floatbank10_b_level                    float64
# rougher.state.floatbank10_c_air                      float64
# rougher.state.floatbank10_c_level                    float64
# ...

# %%
df_full.columns = df_full.columns.str.replace('.', '_')
train.columns = train.columns.str.replace('.', '_')
test.columns = test.columns.str.replace('.', '_')

# %% [markdown]
# **Посчитаем суммарную долю металлов в сырье для тренировочного набора данных и удалим выбросы, которые мы определим в дальнейшем по ходу решения проекта (2.3  Исследуем суммарную концентрацию металлов...).**

# %%
train['rougher_input_feed'] =(
    train['rougher_input_feed_au']
    + train['rougher_input_feed_ag']
    + train['rougher_input_feed_pb']
                                   )
                                    
train['rougher_output_concentrate'] =(
    train['rougher_output_concentrate_au']
    + train['rougher_output_concentrate_ag']
    + train['rougher_output_concentrate_pb']
                                   )

train['primary_cleaner_output_concentrate'] =(
    train['primary_cleaner_output_concentrate_au']
    + train['primary_cleaner_output_concentrate_ag']
    + train['primary_cleaner_output_concentrate_pb']
                                   )
train['final_output_concentrate'] =(
    train['final_output_concentrate_au']
    + train['final_output_concentrate_ag']
    + train['final_output_concentrate_pb']
                                   )

train = train.loc[lambda train: train['rougher_input_feed'] > 8]
train = train.loc[lambda train: train['rougher_output_concentrate'] > 32]
train = train.loc[lambda train: train['primary_cleaner_output_concentrate'] > 43]
train = train.loc[lambda train: train['final_output_concentrate'] > 56]

# %% [markdown]
# **Выделим обучающие и целевые признаки для тренировочной и тестовой выборок.**

# %%
target_rougherv_train = train['rougher_output_recovery']
target_final_train = train['final_output_recovery']

columns = test.columns
train = train[columns]
print(train.shape, test.shape)
# Out:
# (10981, 53) (4537, 53)

# %%
features_rougherv_train = train.loc[:,'rougher_input_feed_au':'rougher_input_floatbank11_xanthate']
features_rougherv_test = test.loc[:,'rougher_input_feed_au':'rougher_input_floatbank11_xanthate']

features_final_train = train.loc[:,'primary_cleaner_input_sulfate':'secondary_cleaner_state_floatbank6_a_level']
features_final_test = test.loc[:,'primary_cleaner_input_sulfate':'secondary_cleaner_state_floatbank6_a_level']

# масштабирование признаков

scal = StandardScaler()
scal.fit_transform(features_rougherv_train)
scal.fit_transform(features_final_train)
# Out:
# array([[-0.63596623,  0.2986871 , -0.19989287, ..., -0.3800017 ,
#         -0.97829739, -2.59234175],
#        [-0.67200206,  0.35017526, -0.19989287, ..., -0.38288789,
#         -1.00675682, -2.43427333],
#        [-0.7165778 ,  0.66287336, -0.19989287, ..., -0.38121117,
#         -1.00111837, -2.47709236],
#        ...,
#        [-0.72736859, -0.34489101, -1.49103196, ..., -0.37181779,
#          0.11114571,  0.13695776],
#        [-0.78904554, -0.36521288, -1.49103196, ..., -0.3650551 ,
#          0.10382709,  0.14361017],
#        [-1.16379974, -0.3675197 , -1.49103196, ..., -0.36555421,
#          0.10799169,  0.13116153]])

# %%
# выделим целевой признак для тестовой выборки

target_rougherv_test = pd.Series(df_full['rougher_output_recovery'], index=test.index)
target_final_test = pd.Series(df_full['final_output_recovery'], index=test.index)

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# ### Посмотрим, как меняется концентрация металлов (Au, Ag, Pb) на различных этапах: в сырье, в черновом концентрате, в концентрате после первой очистки и в финальном концентрате. Какие особенности имеют распределения?.

# %%
df_full
# Out:
#                      date  rougher_input_feed_au  rougher_input_feed_ag  \
# 0     2016-01-15 00:00:00                   6.49                   6.10
# 1     2016-01-15 01:00:00                   6.48                   6.16
# 2     2016-01-15 02:00:00                   6.36                   6.12
# 3     2016-01-15 03:00:00                   6.12                   6.04
# 4     2016-01-15 04:00:00                   5.66                   6.06
# ...                   ...                    ...                    ...
# 19434 2018-08-18 06:59:59                   6.62                   5.99
# 19435 2018-08-18 07:59:59                   6.74                   6.16
# 19436 2018-08-18 08:59:59                   6.63                   6.02
# 19437 2018-08-18 09:59:59                   6.70                   6.10
# 19438 2018-08-18 10:59:59                   6.63                   5.91
#
#        rougher_input_feed_pb  rougher_input_feed_sol  rougher_input_feed_rate  \
# ...

# %%
fig = plt.figure(figsize=(15, 10))
plt.suptitle('Концентрация металлов (Au, Ag, Pb) на различных этапах', fontsize=24, fontweight='bold')
fig.set_facecolor('#eee')

ax1 = plt.subplot(311)
ax1.hist(df_full['rougher_input_feed_au'], bins=100, label='в сырье')
ax1.hist(df_full['rougher_output_concentrate_au'], bins=100, label='в черновом концентрате')
ax1.hist(df_full['primary_cleaner_output_concentrate_au'], bins=100, label='после первой очистки')
ax1.hist(df_full['final_output_concentrate_au'], bins=100, label='в финальном концентрате')
ax1.legend(title='Концентрация Au', fontsize=12, shadow=True, facecolor='c', framealpha=0.4, edgecolor='m')

ax2 = plt.subplot(312)
ax2.hist(df_full['rougher_input_feed_ag'], bins=100, label='в сырье', alpha=0.7)
ax2.hist(df_full['rougher_output_concentrate_ag'], bins=100, label='в черновом концентрате', alpha=0.7)
ax2.hist(df_full['primary_cleaner_output_concentrate_ag'], bins=100, label='после первой очистки', alpha=0.7)
ax2.hist(df_full['final_output_concentrate_ag'], bins=100, label='в финальном концентрате', alpha=0.7)
ax2.legend(title='Концентрация Ag', fontsize=12, shadow=True, facecolor='c', framealpha=0.4, edgecolor='m')

ax3 = plt.subplot(313)
ax3.hist(df_full['rougher_input_feed_pb'], bins=100, label='в сырье', alpha=0.7)
ax3.hist(df_full['rougher_output_concentrate_pb'], bins=100, label='в черновом концентрате', alpha=0.7)
ax3.hist(df_full['primary_cleaner_output_concentrate_pb'], bins=100, label='после первой очистки', alpha=0.7)
ax3.hist(df_full['final_output_concentrate_pb'], bins=100, label='в финальном концентрате', alpha=0.7)
ax3.legend(title='Концентрация Pb', fontsize=12, shadow=True, facecolor='c', framealpha=0.4, edgecolor='m')
plt.xlabel('доля металла')
plt.show()

# %% [markdown]
# #### Вывод
# - Концентрация золота (Au) на каждом этапе увеличивается.
# - Концентрация серебра (Ag) в черновом концентрате увеличивается, а после первой очистки и в финальном концентрате уменьшается.
# - Концентрат свинца (Pb) в черновом концентрате и после первичной очистки уменьшается, но в финальном концентрате остается неизменным после первичной очистки.

# %% [markdown]
# ### Сравним распределения размеров гранул исходного сырья на обучающей и тестовой выборках.
# **Если распределения сильно отличаются друг от друга, оценка модели будет неправильной.**

# %%
fig = plt.figure(figsize=(13,7))
fig.set_facecolor('#eee')
plt.suptitle('Распределения размеров гранул исходного сырья', fontsize=18, fontweight='bold')

plt.hist(train['rougher_input_feed_size'], bins=100, color='r', label='тренировочная выборка')
plt.hist(test['rougher_input_feed_size'], bins=100, color='g', label='тестовая выборка')
plt.legend(fontsize=13, shadow=True, facecolor='c', edgecolor='m', framealpha=0.7, title='Легенда')
plt.minorticks_on()
plt.grid(which='minor', color='#aaa', ls=':')
plt.grid(which='major', color='#444', linewidth=1)
plt.xlabel('Размер гранул', fontsize=13)
plt.ylabel('Частота', fontsize=13)
plt.xlim(0,150)
plt.show()

# %%
fig = plt.figure(figsize=(13, 6))
fig.set_facecolor('#eee')

sns.kdeplot(data=train, x='rougher_input_feed_size');
sns.kdeplot(data=test, x='rougher_input_feed_size');

# %% [markdown]
# #### Вывод
# - Распределения размеров гранул исходного сырья в тренировочной и тестовой выборках одинаковые, это видно по графику плотности.

# %% [markdown]
# ### Исследуем суммарную концентрацию металлов на разных стадиях: в сырье, в черновом концентрате, в концентрате после первой очистки и в финальном концентрате.

# %%
columns = ['rougher_input_feed_au', 'rougher_input_feed_pb', 'rougher_input_feed_ag',
           'rougher_output_concentrate_au','rougher_output_concentrate_pb', 'rougher_output_concentrate_ag',
           'primary_cleaner_output_concentrate_au', 'primary_cleaner_output_concentrate_pb',
           'primary_cleaner_output_concentrate_ag', 'final_output_concentrate_au',
           'final_output_concentrate_pb', 'final_output_concentrate_ag']

total_metal = df_full[columns]
total_metal['rougher_input_feed'] =(
    total_metal['rougher_input_feed_au']
    + total_metal['rougher_input_feed_ag']
    + total_metal['rougher_input_feed_pb']
                                   )
                                    
total_metal['rougher_output_concentrate'] =(
    total_metal['rougher_output_concentrate_au']
    + total_metal['rougher_output_concentrate_ag']
    + total_metal['rougher_output_concentrate_pb']
                                   )

total_metal['primary_cleaner_output_concentrate'] =(
    total_metal['primary_cleaner_output_concentrate_au']
    + total_metal['primary_cleaner_output_concentrate_ag']
    + total_metal['primary_cleaner_output_concentrate_pb']
                                   )
total_metal['final_output_concentrate'] =(
    total_metal['final_output_concentrate_au']
    + total_metal['final_output_concentrate_ag']
    + total_metal['final_output_concentrate_pb']
                                   )

fig = plt.figure(figsize=(15, 10))
plt.suptitle('Суммарная концентрация металлов (Au, Ag, Pb) на различных этапах', fontsize=24, fontweight='bold')
fig.set_facecolor('#eee')

plt.hist(total_metal['rougher_input_feed'], bins=100, label='в сырье')
plt.hist(total_metal['rougher_output_concentrate'], bins=100, label='в черновом концентрате')
plt.hist(total_metal['primary_cleaner_output_concentrate'], bins=100, label='после первой очистки')
plt.hist(total_metal['final_output_concentrate'], bins=100, label='в финальном концентрате')
plt.legend(title='Концентрация металлов', fontsize=12,
           shadow=True, facecolor='c', framealpha=0.7, edgecolor='m')
plt.minorticks_on()
plt.grid(which='minor', color='#aaa', ls=':')
plt.grid(which='major', color='#444', linewidth=1)
plt.show()

# %%
total_metal = total_metal.loc[:,'rougher_input_feed':'final_output_concentrate']

fig = plt.figure(figsize=(14, 6))

sns.kdeplot(data=total_metal);

# %% [markdown]
# **На графике плотности виден "хвост" из низких значений, что является выбросами. Определим выбросы с помощью графика с усами.**

# %%
fig = plt.figure(figsize=(15,8))
total_metal.boxplot();
plt.minorticks_on()
plt.grid(which='minor', color='#aaa', ls=':')

# %%
total_metal = total_metal.loc[lambda total_metal: total_metal['rougher_input_feed'] > 8]
total_metal = total_metal.loc[lambda total_metal: total_metal['rougher_output_concentrate'] > 32]
total_metal = total_metal.loc[lambda total_metal: total_metal['primary_cleaner_output_concentrate'] > 43]
total_metal = total_metal.loc[lambda total_metal: total_metal['final_output_concentrate'] > 56]

fig = plt.figure(figsize=(14, 6))

sns.kdeplot(data=total_metal);
total_metal
# Out:
#        rougher_input_feed  rougher_output_concentrate  \
# 0                   14.87                       38.40
# 1                   14.91                       38.95
# 2                   14.64                       38.65
# 3                   14.20                       38.41
# 4                   13.51                       38.87
# ...                   ...                         ...
# 19432               14.70                       36.27
# 19433               15.99                       36.65
# 19435               15.55                       37.74
# 19436               15.11                       37.82
# 19438               14.98                       37.91
#
#        primary_cleaner_output_concentrate  final_output_concentrate
# 0                                   53.11                     58.14
# 1                                   53.17                     58.70
# 2                                   52.93                     58.93
# ...

# %% [markdown]
# #### Вывод
# - С каждым последующим этапом суммарная доля металлов в концентрате растет.
# - На каждом последующем этапе доля золота в концентрате растет в то время как доля других металлов на первых этапах растет, а на финальном снижается либо остается неизменной относительно предыдущего этапа.

# %% [markdown]
# ## Модель

# %%
# функция для вычисления итоговой sMAPE.

def sMAPE(data, predicts):
    df_sum = ((abs(data - predicts))/((abs(data) + abs(predicts))/2)).sum()
    smape = ((abs(data - predicts))/((abs(data) + abs(predicts))/2)).sum()/len(data) *100
    return smape

def scorrer():
    return make_scorer(sMAPE, greater_is_better=False)

# %% [markdown]
# ### Подберем модель для предсказания эффективности обогащения чернового концентрата (rougher.output.recovery)

# %%
pipelin = Pipeline([('scaler', StandardScaler()),
                    ('model', DecisionTreeRegressor())])

params_1 = [{
    'model': [DecisionTreeRegressor(random_state=42)],
    'model__max_depth':range(1,10),
},
    {
        'scaler': [StandardScaler(), MinMaxScaler()],
        'model': [RandomForestRegressor(random_state=42)],
        'model__max_depth':range(1,5),
        'model__n_estimators':range(1,50,5),
    }]

model_rougherv = GridSearchCV(pipelin,
                       params_1,
                       cv=5,
                       scoring=scorrer(),
                       n_jobs=-1
                      )

model_rougherv.fit(features_rougherv_train, target_rougherv_train)

model_rougherv.best_score_
# Out:
# -5.189080420075458

# %%
params_2 = [{
       'scaler': [StandardScaler(), MinMaxScaler()],
       'model': [LinearRegression()], 
    },
    
    {
      'scaler': [StandardScaler(), MinMaxScaler()],
      'model': [Lasso()],
      'model__alpha': [n/10 for n in range(1, 20)],
      'model__max_iter': range(1000, 10000, 10),
      'model__tol': (1e-6, 1e+6, 'log-uniform')
    }
]

model_rougherv_lin = RandomizedSearchCV(pipelin,
                       params_2,
                       cv=7,
                       scoring=scorrer(),
                       n_iter=50,
                       n_jobs=-1
                      )

model_rougherv_lin.fit(features_rougherv_train, target_rougherv_train)

model_rougherv_lin.best_score_
# Out:
# -5.120887750321848

# %%
model_rougherv_lin.best_estimator_
# Out:
# Pipeline(steps=[('scaler', MinMaxScaler()),
#                 ('model', Lasso(alpha=0.1, tol=1000000.0))])

# %%
model_dummy = DummyRegressor(strategy='mean')
model_dummy.fit(features_rougherv_train, target_rougherv_train)
dummy_pred = model_dummy.predict(features_rougherv_train)
sMAPE(target_rougherv_train, dummy_pred)
# Out:
# 6.033905693046493

# %% [markdown]
# **Вывод:**
# - Модель Lasso показала лучший средний результат.
# - Тест на адекватность показывает, что dummy модель выдает показатель sMAPE=6,03 этот результат хуже обученной модели Lasso с результатом sMAPE=5.1, что говорит об эффуктивности выбранной модели.

# %% [markdown]
# **Посчитаем sMAPE для тестовой выботки.**

# %%
rougher_output_recovery_pred = model_rougherv_lin.predict(features_rougherv_test)
smape_rougherv = sMAPE(target_rougherv_test, rougher_output_recovery_pred)
smape_rougherv
# Out:
# 12.400387003449897

# %% [markdown]
# ### Подберем модель для предсказания эффективности обогащения финального концентрата (final.output.recovery)

# %%
model_final = GridSearchCV(pipelin,
                           params_1,
                           cv=5,
                           scoring=scorrer(),
                           n_jobs=-1)

model_final.fit(features_final_train, target_final_train)

model_final.best_score_
# Out:
# -7.695890083155075

# %%
model_final_lin = RandomizedSearchCV(pipelin,
                                     params_2,
                                     cv=7,
                                     scoring=scorrer(),
                                     n_iter=50,
                                     n_jobs=-1)

model_final_lin.fit(features_final_train, target_final_train)

model_final_lin.best_score_
# Out:
# -7.65996998725418

# %%
model_final_lin.best_estimator_
# Out:
# Pipeline(steps=[('scaler', MinMaxScaler()),
#                 ('model', Lasso(alpha=0.1, max_iter=5920, tol=1e-06))])

# %%
rez = pd.DataFrame(model_final_lin.cv_results_)
rez.sort_values(by='mean_test_score', ascending=False).head()
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 13           0.12          0.08             0.12            0.07
# 14           0.12          0.06             0.11            0.03
# 36           0.12          0.06             0.12            0.04
# 37           0.09          0.06             0.13            0.06
# 45           0.17          0.08             0.05            0.04
#
#         param_scaler param_model__tol param_model__max_iter  \
# 13    MinMaxScaler()             0.00                  5920
# 14  StandardScaler()     1,000,000.00                  3000
# 36  StandardScaler()     1,000,000.00                  4110
# 37  StandardScaler()     1,000,000.00                  7080
# 45  StandardScaler()             0.00                  5650
#
#    param_model__alpha                                 param_model  \
# 13               0.10  Lasso(alpha=0.1, max_iter=5920, tol=1e-06)
# 14               0.20  Lasso(alpha=0.1, max_iter=5920, tol=1e-06)
# ...

# %%
final_output_recovery_pred = model_final_lin.predict(features_final_test)
smape_final = sMAPE(target_final_test, final_output_recovery_pred)
smape_final
# Out:
# 9.162690813804073

# %% [markdown]
# **Посчитаем итоговый sMAPE.**

# %%
sMAPE_total = 0.25 * smape_rougherv + 0.75 * smape_final
sMAPE_total
# Out:
# 9.972114861215529

# %% [markdown]
# ## Вывод
#
# - Лучшие результаты показала модель Lasso с метрикой sMAPE для целевого признака `rougher.output.recovery` равной 12,4 и для `final.output.recovery` равной 9,18.
# - Итоговый sMAPE равен 9,99.
# - Анализ распределения размеров гранул в выборках показал, что фракции исходного сырья одинаковые следовательно результатам предсказаний модели можно дрверять.
# - На каждом этаме обработки сырья концентрация металлов увеличивается. В финальной очистке доля металов остается равной предыдущему этапу за исключением концентрации золота доля которого растет.
# - На графике суммарной концентрации металлов на каждом этапе хорошо видно как доля металлов в сырье увеличивается, что может говорить об эффективности этапов обработки.

# %% [markdown]
# ## Вывод
#
# - Лучшие результаты показала модель линейной регрессии с метрикой sMAPE для целевого признака `rougher.output.recovery` равной 12,91 и для `final.output.recovery` равной 9,83.
# - Итоговый sMAPE равен 10,60.
# - Анализ распределения размеров гранул в выборках показал, что фракции исходного сырья одинаковые следовательно результатам предсказаний модели можно дрверять.
# - На каждом этаме обработки сырья концентрация металлов увеличивается. В финальной очистке доля металов остается равной предыдущему этапу за исключением концентрации золота доля которого растет.
# - На графике суммарной концентрации металлов на каждом этапе хорошо видно как доля металлов в сырье увеличивается, что может говорить об эффективности этапов обработки.

# %% [markdown]
# ## Чек-лист готовности проекта

# %% [markdown]
# - [x]  Jupyter Notebook открыт
# - [x]  Весь код выполняется без ошибок
# - [x]  Ячейки с кодом расположены в порядке выполнения
# - [x]  Выполнен шаг 1: данные подготовлены
#     - [x]  Проверена формула вычисления эффективности обогащения
#     - [x]  Проанализированы признаки, недоступные в тестовой выборке
#     - [x]  Проведена предобработка данных
# - [x]  Выполнен шаг 2: данные проанализированы
#     - [x]  Исследовано изменение концентрации элементов на каждом этапе
#     - [x]  Проанализированы распределения размеров гранул на обучающей и тестовой выборках
#     - [x]  Исследованы суммарные концентрации
# - [x]  Выполнен шаг 3: построена модель прогнозирования
#     - [x]  Написана функция для вычисления итогового *sMAPE*
#     - [x]  Обучено и проверено несколько моделей
#     - [x]  Выбрана лучшая модель, её качество проверено на тестовой выборке
